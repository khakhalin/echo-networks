# %% [markdown]
# # Test whether the model runs forward

# %%
from echo import esn
import numpy as np
import matplotlib.pyplot as plt

# %%
model = esn.Reservoir(7)
model.n_nodes
# Out:
# 7

# %%
x = np.sin(np.linspace(0,3,20))
y = model.run(500, x)
plt.plot(y);
