# %% [markdown]
# # Params justification

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# What's a good default value for the number of edges?

x = np.arange(50)

f = lambda x: max([2, 3*x, int(round(x*(x-1)*0.2))])

plt.plot(x, [f(i) for i in x]);
