# %% [markdown]
# # Top-level simple experiment with the new version of echo

# %%
import numpy as np
import matplotlib.pyplot as plt
from echo import esn

# %%
data = esn.Data.create_source('lorenz')
x,y = data.generate(2000, sampling_step=0.021)
plt.figure(figsize=(12,3))
plt.plot(y);

# %%
model = esn.Reservoir(10)
print(model)
history = model.run(x)
plt.plot(history);
# Out:
# Reservoir of 10 nodes, `ws` type.
