# %% [markdown]
# # Sandbox

# %%
import numpy as np
import matplotlib.pyplot as plt
from echo import esn

# %%
data = esn.Data.create_source('lorenz')

# %%
x,y = data.generate(300, sampling_step=0.021)
plt.plot(x,y);
plt.figure();
plt.plot(x);

# %%
x,y = data.generate(200)
plt.plot(x,y);
plt.figure();
plt.plot(x);
